# %%
# %matplotlib notebook
from libsignetsim.combine.CombineArchive import CombineArchive
from os.path import join

# %%
archive = CombineArchive()
archive.readArchive("combine_archives/specificationL1V2.sedx")
sedml_doc = archive.runMasterSedml()
sedml_doc.showFigures()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
archive.writeArchive("combine_archives/specificationL1V2_fixed.sedx")
archive = CombineArchive()
archive.readArchive("combine_archives/specificationL1V2_fixed.sedx")
sedml_doc = archive.runMasterSedml()
sedml_doc.showFigures()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
