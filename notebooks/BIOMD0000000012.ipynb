# %%
# %matplotlib notebook
from libsignetsim.combine.CombineArchive import CombineArchive

# %%
archive = CombineArchive()
archive.readArchive("combine_archives/BIOMD0000000012.sedx")
sedml_doc = archive.runMasterSedml()
sedml_doc.showFigures()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
archive.writeArchive("combine_archives/BIOMD0000000012_fixed.sedx")
archive = CombineArchive()
archive.readArchive("combine_archives/BIOMD0000000012_fixed.sedx")
sedml_doc = archive.runMasterSedml()
sedml_doc.showFigures()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
